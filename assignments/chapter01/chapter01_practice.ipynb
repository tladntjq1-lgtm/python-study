# %% [markdown]
# ## 실습 제목
#
# ### 1. 요구사항
# 실습과제 1-1
# 학생성적조회
#
# ### 2. 전체 구조
#
# - 데이터:민수 / 85
#
# 지영 / 72
#
# 현우 / 91
#
# - 반복:학생을 한 명씩 확인하고
#
# - 조건:• 80점 이상이면 합격
#
# • 그렇지 않으면 불합격
#
# - 계산/변경:80점이상 합격출력 그렇지 않은사람 불합격 출력
#
# - 결과:
#
# ### 3. 처리 순서
#
# 1.먼저 데이터를 담을 리스트 안에 변수를 정한다
# ex: name=민수 score=85
# 2.데이터들을 리스트 안에 담는다.
#
# 3.반복문을 작성한다
#
# 4.80점이상인 사람은 합격, 그렇지 않은사람은 불합격이라고 나오게 조건문을 작성한다.
#
# 5.출력한다
#
# ### 4. 예상 결과
#
# 민수 현우: 합격 ,지영: 불합격
#
# ### 5. 막힌 부분
#
# 없으면 "없음"이라고 적습니다.
#
#
# ### 6. 실행 후 수정 내용
#
# - 예상과 달랐던 부분:
#
# - 원인:
#
# - 수정한 내용:

# %%
students=[
    {"name": "민수","score":85},
    {"name": "지영","score":72},
    {"name": "현우","score":91},
]
for student in students:
    name=student["name"]
    score=student["score"]
    if score>=80:
        result="합격"
    else:
        result="불합격"
    print(name, score, result)
# Out:
# 민수 85 합격
# 지영 72 불합격
# 현우 91 합격

# %% [markdown]
# ## 실습 1-1. 학생 성적 구조 찾기
#
# - 데이터:학생들의 이름과 점수
# - 여러 개인 것:학생들의 이름과 점수
# - 반복:학생을 한명씩 확인
# - 조건:80점이상이면,합격 그렇지 않으면 불합격
# - 계산/변경:80점이상인 학생들을 계산하고 그렇지 않은 학생들을 계산한다
# - 결과:80점이상인 학생들 과 그렇지 않은 학생들이 나온다.

# %% [markdown]
# ## 실습 1-2. 쇼핑몰 주문 구조 찾기
#
# - 데이터:여러고객의 이름과 주문 금액
#
# - 여러 개인 것:여러고객의 이름과 주문금액
#
# - 반복:고객을 한명씩 확인
#
# - 조건:주문 금액이 50,000원 이상이면 무료배송, 그렇지 않으면 배송비 있음이라고 표시합니다.
#
# - 계산/변경:주문금액이 50000원이상이면 무료배송 그렇지않으면 배송비있음이라고 나온다
#
# - 결과:50000원이상인 사람 무료배송 그렇지 않은사람 배송비있음 출력

# %% [markdown]
# ## 실습 1-3. 상품 재고 구조 찾기
#
# - 데이터:여러상품의 이름과 재고수량
#
# - 여러 개인 것:상품의 이름,재고수량
#
# - 반복:상품을 하나씩 확인
#
# - 조건:재고가 1개이상이면
#
# - 계산/변경:재고가 1개 이상이면 판매가능 그렇지않으면 품절을 나타냄
#
# - 결과:1개이상인 재고는 판매가능이 나오고 그렇지않은 1개 미만인 경우는 품절이라고 나온다
#
# ### 앞의 두 문제와 같은 구조
#
# 내 생각:똑같은 구조의 문제이지만 객체와 변수가 다르다

# %%
students=[
    {"name":"민수", "score":85},
    {"name":"지영", "score":72},
    {"name":"현우", "score":91},
]

# %% [markdown]
# 다음 데이터를 List 안의 Dictionary 형태로 직접 작성하세요.
#
#
#
# 민수 / 85
#
# 지영 / 72
#
# 현우 / 91
#
#
# ### 설명
#
# - 왜 전체 학생은 List인가?
# 데이터 여러개를 담으려면 리스트가 필요해서 전체학생은 리스트이다
# - 왜 학생 한 명은 Dictionary인가?
# 학생한명당 딕셔너리 안에 키와 밸류를 가지고 있어야 하기에 딕셔너리이다
# - `name`은 무엇을 의미하는가?
# 객체를 담을 변수이다
# - `score`는 무엇을 의미하는가?
# 객체를 담을 변수이다

# %%
orders=[
    {"customer":"민수", "amount":45000},
    {"customer":"지영", "amount":72000},
    {"customer":"현우", "amount":53000},
]

# %% [markdown]
# ### 설명
#
# - List 안에는 무엇이 들어 있는가?
# 주문자와 주문금액
# - 주문 한 건을 Dictionary로 표현한 이유는 무엇인가?
# 동일하게 키와밸류를 담으려고
# - 학생 데이터와 달라진 것은 무엇인가?
# 객체와 변수명
# - 학생 데이터와 그대로인 구조는 무엇인가?
# 객체와 변수명, 리스트안에 딕셔너리가 있는 구조

# %%
product=[
    {"name":"키보드", "stock": 3},
    {"name":"마우스", "stock": 0},
    {"name":"모니터", "stock": 5},
]

# %% [markdown]
# ## 실습 3-1
#
# - 반복되는 대상:학생과 학생점수
#
# - 한 번 반복할 때 현재 데이터:변수안에 들어간다
#
# - 현재 데이터에서 필요한 Key:name과 score
#
# - 예상 반복 횟수:3

# %%
students=[
    {"name":"민수","score":85},
    {"name":"지영","score":72},
    {"name":"현우","score":91},
]
for student in students:
    name=student["name"]
    score=student["score"]

# %% [markdown]
# - `orders` 전체와 `order` 한 개의 차이는 무엇인가?
# 오더스는 리스트안에 있는 주문여러개이고 오더는 리스트안에 잇는 딕셔너리 주문 한개이다.
# - 반복문은 몇 번 실행될 것인가?
# 3
# - 현재 고객 이름은 어디에서 가져오는가?
# order안에있는 customer 변수
# - 현재 주문 금액은 어디에서 가져오는가?
# order안에있는 amount 변수

# %%
#실습3-2 주문 한건씩 출력

orders=[
    {"customer":"민수","amount":45000},
    {"customer":"지영","amount":72000},
    {"customer":"민수","amount":53000},
    ]
for order in orders:
    customer=order["customer"]
    amount=order["amount"]

# %%
#실습3-3 상품 한 개씩 출력

products=[
    {"name": "키보드", "stock":3},
    {"name": "마우스", "stock":0},
    {"name": "모니터", "stock":5},
]
for product in products:
    name=product["name"]
    stock=product["stock"]

# %%
#실습 4-1 점수 판단
# 예상결과 주석으로 진행
#스코어가 85 일때는 80점이상 에 적합하여 참이니까 합격이 출력된다
score=79
if score >=80:
    print("합격")
else:
    print("불합격")
# Out:
# 불합격

# %%
#4-2 실습 주문 금액 판단
amount=49000
if amount>=50000:
    print("무료배송")
else:
    print("배송비 있음")
# Out:
# 배송비 있음

# %% [markdown]
# ### 경계값 확인
#
# - 49,000원 결과:배송비 있음
#
# - 50,000원 결과:무료배송
#
# - 51,000원 결과:무료배송
#
# - 왜 50,000원을 꼭 테스트해야 하는가?
# 경계값이어서

# %%
#실습 4-3 재고판단
stock=10
if stock>=1:
    print("판매가능")
else:
    print("품절")
# Out:
# 판매가능

# %%
#실습 5-1
name="민수"
score=85
if score>=80:
    result="합격"
else:
    result="불합격"
print(name,score,result)
# Out:
# 민수 85 합격

# %%
#실습 5-2
customer="지영"
amount=72000
if amount>=50000:
    result="무료배송"
else:
    result="배송비있음"
print(customer,amount,result)
# Out:
# 지영 72000 무료배송

# %%
#실습 5-3
name="마우스"
stock=0
if stock>=1:
    result="재고있음"
else:
    result="품절"
print(name,stock,result)
# Out:
# 마우스 0 품절

# %% [markdown]
# ## 종합 실습 N. 문제 제목
#
# ### 1. 요구사항을 내 말로 다시 쓰기
# 학생여러명의 성적을 한명씩 조회하여 80점 이상이면 합격 미만이면 불합격으로  이름과 점수 결과를 한번에 출력한다. 한마디로 학생의 합격/ 불합격 조회
# ### 2. 전체 구조
#
# - 데이터:민수 /85, 지영/72, 현우/91 , 수진/80
#
# - 반복:학생을 한명식 확인
#
# - 조건:80점이상이면 합격 그렇지 않으면 불합격
#
# - 계산/변경:이름 점수 결과 출력
#
# - 결과:민수 합격 /지영 불합격 /현우 합격 /수진 합격
#
# ### 3. 처리 순서
#
# 1.students라는 변수를 만든다.
#
# 2.리스트를 만들고 그안에 한명씩 딕셔너리안에 값을 넣는다.
#
# 3.반복문을 만든다
#
# 4.80점 이상의 학생은 합격 미만은 불합격이게 조건문을 만든다
#
# 5.이름,점수,결과를 출력한다.
#
# 6.80점 이상인 학생들은 이름, 점수, 합격이 출력되고 미만인 학생들은 이름, 점수. 불합격이 출력된다
#
# ### 4. 예상 결과
# - 결과:민수 합격 /지영 불합격 /현우 합격 /수진 합격
#
# ### 5. 코드 작성 전 확인
#
# - List가 필요한 이유:여러개의 데이터를 담으려고
#
# - Dictionary가 필요한 이유:하나의 데이터를 담으려고
#
# - for가 필요한 이유:학생한명씩 확인하기위해서
#
# - if/else가 필요한 이유:조건의 참을 보기위해서
#
# - 최종 출력에 필요한 값:점수,이름,결과

# %% [markdown]
# ### 학생 문제와 주문 문제 비교
#
# - 학생 문제의 여러 대상:학생들,점수
#
# - 주문 문제의 여러 대상:주문자들,주문금액
#
# - 학생 문제의 기준:80점이상 합격여부
#
# - 주문 문제의 기준:50000원이상 무료배송
#
# - 학생 문제의 결과:학생의 점수와 합격/불합격 출력
#
# - 주문 문제의 결과:주문자 정보와 가격 무료배송 / 배송비 있음 출력
#
# ### 공통 구조
# 한명씩 꺼내서 쓴다, ~면 조건이 있다 , 여러데이터들이 있다.

# %% [markdown]
# 이번 문제부터는 처리 순서를 도움 없이 직접 6단계 이내로 작성하세요.
# - 종합 실습 3 — 상품 재고 상태
#
#
# 1. 여러데이터들을 확인하고 그들이 공통되는 변수명을 적습니다.
#
# 2. 변수명= 리스트를 적고 그안에 딕셔너리를 넣고 데이터들을 적습니다.
#
# 3. 상품을 하나씩 확인하는 반복문을 씁니다
#
# 4. 공통되는객체 하나당 변수를 정합니다.
#
# 5. 재고가 1개 이상이면 판매가능 그렇지 않으면 품절을 결과에 담습니다
#
# 6. 상품,재고, 판매가능여부(결과)를 출력합니다

# %% [markdown]
# - 종합 실습 4 — 출석률 확인
#
# 민수 / 92
#
# 지영 / 74
#
# 현우 / 88
#
# 수진 / 79
# 데이터는 학생 이름과 출석률입니다.
#
# 요구사항
#
# • 출석률이 80 이상 → 출석 충족
#
# • 그 외 → 출석 부족
# 이름, 출석률, 결과를 출력합니다.
# 이번 문제에서는 문제 설명에 List, Dictionary, for, if라는 단어가 없습니다.
# 어떤 Python 도구가 필요한지 문제 구조를 보고 직접 결정하세요
#
# 학생 한명씩 확인하라는 말이 없어서 for는 필요없을 것 같다.
# 리스트, 딕셔너리,if,else,변수등이 필요할것같다.

# %%
students = [
    {"name": "민수", "attendance": 92},  # 0번
    {"name": "지영", "attendance": 74},  # 1번
    {"name": "현우", "attendance": 88},  # 2번
    {"name": "수진", "attendance": 79},  # 3번
]


student = students[0]
name = student["name"]
attendance = student["attendance"]
if attendance >= 80:
    result = "출석충족"
else:
    result = "출석부족"
print(name, attendance, result)


student = students[1]
name = student["name"]
attendance = student["attendance"]
if attendance >= 80:
    result = "출석충족"
else:
    result = "출석부족"
print(name, attendance, result)

student = students[2]
name = student["name"]
attendance = student["attendance"]
if attendance >= 80:
    result = "출석충족"
else:
    result = "출석부족"
print(name, attendance, result)

student = students[3]
name = student["name"]
attendance = student["attendance"]
if attendance >= 80:
    result = "출석충족"
else:
    result = "출석부족"
print(name, attendance, result)
# Out:
# 민수 92 출석충족
# 지영 74 출석부족
# 현우 88 출석충족
# 수진 79 출석부족

# %%
city_temps=[
    {"city":"서울","temp":34},
    {"city":"부산","temp":29},
    {"city":"대전","temp":33},
    {"city":"광주","temp":31},
]
for city_temp in city_temps:
    city=city_temp["city"]
    temp= city_temp["temp"]
    if temp>=33:
        result="폭염주의"
    else:
        result="일반"
    print(city,temp,result)
# Out:
# 서울 34 폭염주의
# 부산 29 일반
# 대전 33 폭염주의
# 광주 31 일반

# %% [markdown]
# ### 요구사항 분석
# 회원별 누적 구매액 확인하고  100,000원 이상 회원 우수회원 아니면 일반회원으로 회원을 구분하는 것
# ### 전체 구조
# 회원별 누적 구매액으로 회원구분
# ### 처리 순서
# 데이터를 리스트와 딕셔너리 안에 담고 포문으로 한명씩 꺼내고
# 회원과 회원누적금액을 변수안에 담고
# 누적금액 10만원이상 인 조건문 을 만들어서
# 결과를 우수회원으로 담는다
# 그렇지않으면 일반회원으로 담는다
# 그리고 회원이름 구매액 회원구분을 출력한다
# ### 예상 결과
# 민수 우수회원/ 지영 일반회원/ 현우 우수회원/ 수진 일반회원
# ### 필요한 Python 도구와 그 이유
# for, if ,list,dictionary,else

# %%
total_orders=[
    {"customer":"민수", "amount":120000},
    {"customer":"지영", "amount":85000},
    {"customer":"현우", "amount":210000},
    {"customer":"수진", "amount":99000},    
]
for total_order in total_orders:
    customer=total_order["customer"]
    amount=total_order["amount"]
    if amount>=100000:
        result="우수회원"
    else:
        result="일반회원"
    print(customer,amount,result)
# Out:
# 민수 120000 우수회원
# 지영 85000 일반회원
# 현우 210000 우수회원
# 수진 99000 일반회원

# %% [markdown]
# 19. 종합 실습을 모두 마친 뒤 비교하기
#
#
#
# 6개의 종합 실습을 모두 끝낸 다음 아래 표를 Notebook의 Markdown 셀에 직접 작성합니다.
#
#
#
# ## 종합 실습 구조 비교
#
#  문제  여러 대상 확인할 값  조건  결과
#
#
# | 학생 성적
#
# | 주문 배송
#
# | 상품 재고
#
# | 출석률
#
# | 기온
#
# | 회원 구매액
#
# 모두 조건이 참일때 출력되는 값과 아닐떄 출력되는 값을 이용한다.
#
#
# 표를 작성한 다음 아래 질문에 답하세요.
#
#
#
# ### 내가 발견한 공통 구조
#
# 1.모두 조건이 참일때 출력되는 값과 아닐떄 출력되는 값을 이용한다.
#
# 2.한명 혹은 한개 씩 꺼내어서 확인한다.
#
# 3.데이터가 여러개이다.
#
# ### 문제의 소재가 바뀌어도 유지된 Python 구조
# list,dictionary,for,if,else
# ### 가장 어려웠던 문제와 이유
# 아직 변수를 어떻게 적어야할지 어려웠다 특히 그냥 주어진 객체에 변수를 달기는 쉬웠지만 그걸 통틀어서 뭐라고 정할지 아직 잘모르겠다.

# %% [markdown]
# 20. Chapter 02 준비 코드 — 반드시 직접 입력
# 아래 코드는 복사해서 붙여 넣지 마세요.
# 눈으로 보고 한 줄씩 직접 입력합니다.
#
# students=[
#    {"name":"민수", "score":95, "attendance":90},
#    {"name":"지영", "score":85, "attendance":95},
#    {"name":"현우", "score":72, "attendance":65},
#    {"name":"수진", "score":78, "attendance":88},
# ]
# for student in students:
#
#     name = student["name"]
#
#     score = student["score"]
#
#     attendance = student["attendance"]
#
#     if score < 60 or attendance < 70:
#
#         grade = "F"
#
#     elif score >= 90 and attendance >= 80:
#
#         grade = "A"
#
#     elif score >= 80 and attendance >= 80:
#
#         grade = "B"
#
#     elif score >= 70:
#
#         grade = "C"
#
#     else:
#
#         grade = "D"
#
#     print(
#
#         f"{name}: 점수 {score}점, "
#
#         f"출석률 {attendance}%, 등급 {grade}"
#     )

# %% [markdown]
# ## Chapter 02 준비 코드 분석
#
# ### 데이터
#
# - 학생 한 명이 가진 Key:name,score,attendance
#
# - 학생 한 명이 가진 값의 개수:3
#
# ### 반복
#
# - 무엇을 하나씩 확인하는가? 학생하나의 데이터
#
# ### 조건
#
# - F가 되는 조건:점수 60점이하 출석률 70퍼이하
#
# - A가 되는 조건:점수 90점이상 출석률 80퍼이상
#
# - B가 되는 조건:점수 80점이상 출석률80퍼이상
#
# - C가 되는 조건:점수70점이상
#
# - D가 되는 조건:조건에 취합하지 않는 나머지
#
# ### 새로운 표현
#
# - `and`를 사용한 곳:A,B
#
# - `or`를 사용한 곳:F
#
# - `elif`가 필요한 이유를 지금 생각해 본 내용:
# 조건을 여러개 써야해서
#
# - f-string에서 `{name}`의 역할을 지금 생각해 본 내용:
# 학생의 이름

# %%
students = [

    {"name": "민수", "score": 90, "attendance": 80},

    {"name": "지영", "score": 89, "attendance": 80},

    {"name": "현우", "score": 95, "attendance": 69},

    {"name": "수진", "score": 78, "attendance": 88}

]

for student in students:

    name = student["name"]

    score = student["score"]

    attendance = student["attendance"]

    if score < 60 or attendance < 70:

        grade = "F"

    elif score >= 90 and attendance >= 80:

        grade = "A"

    elif score >= 80 and attendance >= 80:

        grade = "B"

    elif score >= 70:

        grade = "C"

    else:

        grade = "D"

    print(

        f"{name}: 점수 {score}점, "

        f"출석률 {attendance}%, 등급 {grade}"

    )
# Out:
# 민수: 점수 90점, 출석률 80%, 등급 A
# 지영: 점수 89점, 출석률 80%, 등급 B
# 현우: 점수 95점, 출석률 69%, 등급 F
# 수진: 점수 78점, 출석률 88%, 등급 C

# %% [markdown]
# ## Chapter 02 준비 코드 값 변경 실험
#
# ### 실험 1
#
# - 변경한 값:민수: score:95->80  attendance90->80
#
# - 예상 등급:B
#
# - 실제 등급:B
#
# - 예상과 실제가 같은가?예
#
# ### 실험 2
#
# - 변경한 값:지영: score:85->89  attendance80->95
#
# - 예상 등급:B
#
# - 실제 등급:B
#
# - 예상과 실제가 같은가?Yes
#
# ### 실험 3
#
# - 변경한 값:현우: score:72->95  attendance65->69
#
# - 예상 등급:F
#
# - 실제 등급:F
#
# - 예상과 실제가 같은가?Yes

# %% [markdown]
# 23. 다음 시간까지 암기해야 하는 수준
#
#
#
# 다음 수업 시작 후 5분 안에 아무 자료도 보지 않고 Chapter 02 준비 코드를 작성합니다.
#
#
#
# 단순히 글자를 외우는 것만으로 끝나지 않습니다.
#
#
#
# 다음 질문에도 답할 준비를 합니다.
#
#
#
# 1. `attendance`가 왜 추가되었는가?
# 출석률 부분을 확인하려고
# 2. `and`와 `or`는 코드에서 각각 어디에 사용되었는가?
# and는 B와A or은 F에서 사용됐다
# 3. 왜 `if` 다음에 여러 개의 `elif`가 있는가?
# 여러개의 조건식을 확인하려고
# 4. 조건의 순서를 바꾸면 결과가 달라질 수 있는가?
# 아니요
# 5. `grade`는 언제 만들어지는가?
# 조건에 들어맞을때
# 6. f-string의 `{name}`, `{score}`, `{attendance}`, `{grade}`는 무엇인가?
# 이름 점수 출석률 평가등급

# %% [markdown]
# ## 암기 연습 기록
#
# - 1회차: 완료
#
# - 2회차: 완료 (미숙)
#
# - 3회차: 미완료
#
# - 5분 무자료 작성: 미완료
#
# ### 가장 자주 틀린 부분
# f스트링을써서 출력하는 부분

# %% [markdown]
# # AI 사용 기록
#
# ## AI 사용 횟수
#
# 총 5__회
#
# ---
#
# ## AI 질문 1
#
# ### 질문하기 전에 내가 먼저 한 것
#
# - 내가 생각한 내용:리스트안에 있는 딕셔너리 안에 있는 내용들이 반복문을 만나면 6번 반복되는줄 알았다.
#
# - 공식 문서에서 확인한 내용:
#
# - 해결되지 않은 부분:
#
# ### 내가 AI에게 입력한 질문
# key와 value
#
# list안에있는 딕셔너리가 반복되는 구조를 초등학생도 알 수 잇게 설명해줘
#
#
# ### AI의 답변
#
# 1. Key(키)와 Value(값)란?
# "이름표와 내용물"이에요.
#
# 우리가 문방구에서 상자를 샀다고 해볼게요. 상자 겉면에는 이름표(Key)가 붙어 있고, 상자 안을 열어보면 내용물(Value)이 들어있어요.
#
# Key (이름표): "이름", "나이", "좋아하는 과자"
#
# Value (내용물): "민수", "10살", "초코파이"
#
# 이 상자 하나를 프로그래밍에서는 '딕셔너리'라고 불러요.
#
# 2. List(리스트) 안에 있는 딕셔너리 구조란?
# "여러 명의 상자를 담아둔 커다란 가방"이에요.
#
# 학급 친구들의 정보 상자를 커다란 책가방(List) 안에 차곡차곡 넣어둔 거랍니다.
#
# 가방(List): [ 첫 번째 상자, 두 번째 상자, 세 번째 상자 ]
#
# 1번 상자(딕셔너리): { 이름표: "민수", 점수: 85 }
#
# 2번 상자(딕셔너리): { 이름표: "지영", 점수: 72 }
#
# 3번 상자(딕셔너리): { 이름표: "현우", 점수: 91 }
#
# 3. 반복문(for문)을 돌린다는 건 무슨 뜻일까?
# 가방에서 상자를 하나씩 꺼내서 확인하는 행동이에요.
#
# 가방에서 1번 상자를 꺼냅니다. (민수 상자)
#
# → "이름표('name')를 보니 민수네! 점수표('score')를 보니 85점이네!"
#
# 가방에서 2번 상자를 꺼냅니다. (지영 상자)
#
# → "이름표('name')를 보니 지영이네! 점수표('score')를 보니 72점이네!"
#
# 가방에서 3번 상자를 꺼냅니다. (현우 상자)
#
# → "이름표('name')를 보니 현우네! 점수표('score')를 보니 91점이네!"
#
# 가방 안에 상자가 3개 들어있으니, 손을 넣어서 꺼내는 행동을 똑같이 3번 반복하면 끝납니다!
#
# 한 줄 요약:
#
# List는 여러 상자를 담는 가방, 딕셔너리는 이름표(Key)가 붙은 정보 상자, for문은 가방에서 상자를 하나씩 꺼내 보는 동작입니다!
#
# ### 답변을 보고 내가 한 일
#
# - 코드 복사 여부: 없음
#
# - 참고한 개념:키와밸류 하나씩 다 반복되는줄 알았는데 딕셔너리(상자) 하나만 반복되는 구조를 알게 됐다
#
# - 내가 직접 다시 생각한 내용:위에 내용을 알게되었고 6번이 아닌 3번만 반복되는 구조를 알게 되었다.
#
# ---
#
# ## AI 질문 2
#
# ### 질문하기 전에 내가 먼저 한 것
#
# - 내가 생각한 내용:students안에 있는 student는 왜 단수형을 쓸까?
#
# - 공식 문서에서 확인한 내용:student라는 단수형 변수를 만들어서 students와 같은 변수명을 쓰지 않았어야한다.
#
# - 해결되지 않은 부분:
#
# ### 내가 AI에게 입력한 질문
#
# Python
#
#
#
# students = [
#
# {"name": "민수", "score": 85}, # 0번 요소
#
# {"name": "지영", "score": 72}, # 1번 요소
#
# {"name": "현우", "score": 91} # 2번 요소
#
# ]for student in students:
#
# name = student["name"]
#
# score = student["score"]
#
# 이 반복문에서 in 앞에 students가아닌 student를 쓰는이유를 아까처럼 쉽게 설명해줬으면 좋겠어 이 이후에 쓰는 조건문은 써주지 않아도 괜찮아
#
# 저 질문에 대한 답변만 해줘.
#
#
#
# ### AI의 답변
# 왜 in 앞에 students를 쓰면 안 될까요?
# in 뒤에는 전체 보물상자가 들어있는 가방(students)이 와야 하고, in 앞에는 하나씩 꺼내서 담을 임시 상자 이름(student)이 와야 합니다.
#
# 만약 for students in students: 라고 쓰면, "가방 이름도 가방이고, 꺼낸 상자 이름도 가방"이라고 부르는 꼴이라 컴퓨터가 헷갈려 하게 됩니다.
#
# 그래서 가방 이름은 여러 개를 뜻하는 students, 꺼낸 상자 1개는 단수를 뜻하는 student로 구분해서 써주는 것입니다!
#
#
# ### 답변을 보고 내가 한 일
#
# - 코드 복사 여부: 없음
#
# - 참고한 개념:원래코드
#
# - 내가 직접 다시 생각한 내용:포문에서 복수형변수와 단수형변수의 구분을 알게되었다.

# %% [markdown]
# # 저 질문과 이해를 하기위해 꼬리질문
#
# 1. ai에게 한 질문
#
# - 현재 고객 이름은 어디에서 가져오는가?
#
#
#
# - 현재 주문 금액은 어디에서 가져오는가?
#
# 이건 둘다 order인가요 그럼?
#
# 2. ai 답변
#
# 네, 맞습니다! 둘 다 order에서 가져옵니다.
#
# 더 정확히 구분하면 다음과 같습니다:
#
# 현재 고객 이름: order["customer"] (변수 order에 들어있는 딕셔너리의 "customer" Key에서 가져옴)
#
# 현재 주문 금액: order["amount"] (변수 order에 들어있는 딕셔너리의 "amount" Key에서 가져옴)

# %% [markdown]
# ## AI 질문 4
#
# ### 질문하기 전에 내가 먼저 한 것
#
# - 내가 생각한 내용:for문을 쓰지않고 리스트값을 하나씩 가져와서 출력하는방법
#
# - 공식 문서에서 확인한 내용:[0],[1]....등을 사용하여 출력한다
#
# - 해결되지 않은 부분:어떻게 이어서 진행할지 고민이었다
#
# ### 내가 AI에게 입력한 질문
# for문 말고 list안에서 [0] [1]등으로 가져오는 방법을 알고 싶어 코드의 정답은 쓰지말고 어떤방식으로 써야하는지 예시를 작성해줘
#
# ### AI의 답변
#
# 리스트 안의 딕셔너리 데이터를 for문 없이 [0], [1] 같은 인덱스로 가져오는 핵심 원리와 작성 방식 예시입니다.
#
# 기본 규칙: "가방 위치 번호 + 상자 이름표"
# 가방에서 몇 번째 상자인지 고르기: 리스트이름[인덱스번호]
#
# 그 상자에서 어떤 이름표를 볼지 지정하기: ["Key이름"]
#
# 이 두 가지를 연속해서 붙여 쓰면 됩니다.
#
# 작성 방식 예시
# 데이터가 담긴 변수를 data_list라고 할 때, 각 위치의 데이터는 다음과 같은 방식으로 꺼냅니다.
#
# Python
# # 1번째(0번) 데이터 가져오는 방식
# first_name = data_list[0]["name"]
# first_score = data_list[0]["score"]
#
# # 2번째(1번) 데이터 가져오는 방식
# second_name = data_list[1]["name"]
# second_score = data_list[1]["score"]
#
# # 3번째(2번) 데이터 가져오는 방식
# third_name = data_list[2]["name"]
# third_score = data_list[2]["score"]
# 한 줄씩 풀어쓴 예시 (이해용)
# 위 과정을 줄이지 않고 두 단계로 나누어 쓰면 다음과 같습니다.
#
# Python
# # 0번 위치에 있는 상자 전체를 먼저 변수에 담기
# item = data_list[0]
#
# # 그 상자에서 Key를 지정해 값 꺼내기
# name = item["name"]
# score = item["score"]
# 핵심 요약:
#
# data_list[0]은 0번 위치의 딕셔너리 상자 전체를 뜻하고, 뒤에 ["name"]을 이어 붙인 data_list[0]["name"]은 그 상자 안에 들어있는 'name'의 값을 바로 지칭하게 됩니다.
#
# ### 답변을 보고 내가 한 일
#
# - 코드 복사 여부: 없음
#
# - 참고한 개념:변수를 하나씩 만들어서 호출 하는 방식
#
# - 내가 직접 다시 생각한 내용:변수를 하나씩 만들어서 호출 하는 방식적용

# %% [markdown]
# ## AI 질문 5
#
# ### 질문하기 전에 내가 먼저 한 것
#
# - 내가 생각한 내용:서울의 온도 등 각지역의 온도를 담을 큰변수를 뭐라고 지정하면 좋을까?
#
# - 공식 문서에서 확인한 내용:두개를 합쳐 만드는 경우가 종종 있음
#
# - 해결되지 않은 부분:아직 변수명을 정하지 못함
#
# ### 내가 AI에게 입력한 질문
#
# 서울 / 34
#
# 부산 / 29
#
# 대전 / 33
#
# 광주 / 31
#
# 서울 부산 대전 광주 =city
#
# 34,29,33,31은 =temperature
#
# 이걸 담을건 어떤 변수이름으로 쓰면 좋을까?
#
#
#
# ### AI의 답변
#
# 데이터의 특성과 파이썬의 관례에 맞춰 추천하는 변수 이름 목록입니다.
#
# 1. 리스트(List) 형태일 때
#
# 도시 목록과 기온 목록을 각각 따로 담을 때 좋은 이름입니다.
#
# 도시 변수: cities (가장 추천), city_list
#
# 기온 변수: temperatures (가장 추천), temps (줄임말)
#
# 2. 딕셔너리(Dictionary) 형태일 때
#
# '서울: 34'처럼 도시와 기온을 짝지어 하나로 묶어 담을 때 좋은 이름입니다.
#
# city_temperatures (가장 추천)
#
# city_temps
#
# temperatures_by_city
#
# 추천 이유
# 프로그래밍에서는 여러 개의 값이 모인 데이터(리스트)를 다룰 때 단수형(city) 대신 복수형(cities, temperatures)을 사용하는 것이 관례입니다.
#
# 도시와 기온을 한 짝으로 연결해서 관리하는 경우가 많으므로, 두 단어를 결합한 city_temperatures가 코드의 의미를 파악하기에 가장 좋습니다.
#
# ### 답변을 보고 내가 한 일
#
# - 코드 복사 여부: 없음
#
# - 참고한 개념:변수명 예시를 보고 참고했다
#
# - 내가 직접 다시 생각한 내용:큰변수는  city_temps로 정하고
# 도시의 변수들은 city  온도는 temp로 정했다.

# %% [markdown]
# 26. 최종 회고
# # Chapter 01 최종 회고
#
# ## 1. 이번 과제에서 가장 많이 반복한 문제 해결 구조는 무엇인가?
# 여러개의 데이터의 참 거짓을 판별하여 참일떄 결과 출력과 거짓일때 출력결과를 한명씩 나타낸것
# ## 2. 문제를 보자마자 코드를 작성하는 습관이 줄었는가?
# 아직은 좀 있는거 같으나 수도코드를 작성해보면서 습관이 조금은 줄은 것 같다.
# ## 3. 가장 어려웠던 세부 기술은 무엇인가?
# 변수명을 정하는것과 for문에 대한 이해도가 조금 적었던 것 같다.
# ## 4. 6개의 종합 실습 중 가장 쉽게 풀린 문제는 무엇인가?
# 조건문을 작성하는 부분이 좀 쉬웠던 것 같다.
# 왜 쉬웠는가?튜터님이 python 수업 당시에 설명해주실떄 집중해서 잘들어서 좀 쉬웠던 것 같다.
#
# ## 5. 다른 소재의 문제에서도 같은 구조를 찾을 수 있었는가?
# 구조는 동일하고 데이터만 틀렸다.
# ## 6. AI를 몇 번 사용했는가?
# 5회
# ## 7. AI에게 질문하지 않고 해결한 것은 무엇인가?
# 전에 작성한 코드를 보거나 오류가 났을 때 한번더 생각해보고 뺴먹은건 없는지 보고 해결한 경험이 있다.
# ## 8. Python 공식 튜토리얼에서 확인한 내용은 무엇인가?
# 포 루프 예제 결과 4가지
# ## 9. Chapter 02 준비 코드에서 아직 이해되지 않는 부분은 무엇인가?
# 정확한 구조파악 아직 정확히 안됨
# ## 10. 다음 수업 전 다시 연습할 것은 무엇인가?
# 코드 외워가기!
